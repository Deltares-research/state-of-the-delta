# %% [markdown]
# ### Create RAG

# %%
# Packages
from pathlib import Path

from dotenv import load_dotenv

from memo_gen.rag import create_embeddings_and_index, get_retriever

# Load environment variables
load_dotenv()
# Out:
# c:\Users\white_rn\OneDrive - Stichting Deltares\Desktop\memo-gen\.venv\Lib\site-packages\langgraph\checkpoint\base\__init__.py:17: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer
# True

# %% [markdown]
# ### Settings

# %%
# Directories
repo_path = Path.cwd().parents[0]
dir_path_docs = repo_path / "docs"

# Area of interest
index = "minikennisbank_nbs"

file_paths = list((dir_path_docs / index).glob("*.pdf"))
print("Number of files found:", len(file_paths))
# Out:
# Number of files found: 2

# %%
create_embeddings_and_index(file_paths=file_paths, index_name=index)
# Out:
# Embedding files:   0%|          | 0/2 [00:00<?, ?it/s]
# INFO:httpx:HTTP Request: POST https://openaicoastal.openai.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openaicoastal.openai.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openaicoastal.openai.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openaicoastal.openai.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://openaicoastal.openai.azure.com/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# ...

# %%
# Retrieve a summary of the documents using the RAG system
query = "Create a brief summary of the documents."

retriever = get_retriever(index_name=index)
results = retriever.invoke(query)
[result["chunk"] for result in results]
